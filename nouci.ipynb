# %% [markdown]
# # Resultado de los datos de los antibióticos y sus respuestas (NO UCI)
# Se grafican los resultados de las respuestas de los antibióticos en 36 meses, desde julio del 2018 hasta junio del 2021

# %% [markdown]
# ## Se cargan y se limpian los datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
datos = pd.read_excel("datos_antibioticos_NO_UCI.xlsx", index_col=0)
datos = datos.T
datos.head()
# Out:
#             VANCOMICINA  CEFTRIAXONA  CEFEPIMA  MEROPENEM  ERTAPENEM  \
# JULIO               3.6          9.3       8.9        9.6        2.9
# AGOSTO              2.4          6.6       5.1        4.7        4.2
# SEPTIEMBRE          2.2          5.2       6.1        7.2        4.3
# OCTUBRE             4.2          6.6       5.3        6.7        1.3
# NOVIEMBRE           5.1          7.7       7.9        3.6        4.9
#
#             PIPERACILINA TAZOBACTAM  COLISTINA  LINEZOLID  POLIMIXINA B  \
# JULIO                           7.4        0.7        1.0           1.2
# AGOSTO                          8.4        0.1        1.3           0.7
# SEPTIEMBRE                      3.1        0.1        1.7           2.8
# OCTUBRE                         6.5        0.0        7.4           2.5
# NOVIEMBRE                       6.9        0.1        2.8           0.6
#
#             k pneumonie R meropenem  k pneumonie R píptazo  \
# JULIO                      0.065941               0.049456
# AGOSTO                     0.028466               0.028466
# SEPTIEMBRE                 0.000000               0.000000
# OCTUBRE                    0.000000               0.000000
# NOVIEMBRE                  0.028401               0.042602
#
#             p.aeruginosa R meropenem  p.aeruginosa R piptazo     sarrm
# JULIO                       0.016485                0.032971  0.049456
# AGOSTO                      0.014233                0.000000  0.071164
# SEPTIEMBRE                  0.000000                0.000000  0.063101
# OCTUBRE                     0.043253                0.014418  0.028835
# NOVIEMBRE                   0.028401                0.014201  0.071003

# %%
x = np.linspace(1,36, 36)

# %% [markdown]
# ## Gráfica general de las tablas 1 y 2 (NO UCI)

# %%
plt.figure(figsize=(14,5))
plt.plot(x, datos["VANCOMICINA"], '-', label="VANCOMICINA")
plt.plot(x, datos["CEFTRIAXONA"], '--', label="CEFTRIAXONA")
plt.plot(x, datos["CEFEPIMA"], ':', label="CEFEPIMA")
plt.plot(x, datos["MEROPENEM"], 'v-', label="MEROPENEM")
plt.plot(x, datos["ERTAPENEM"], 'o-', label="ERTAPENEM")
plt.plot(x, datos["PIPERACILINA TAZOBACTAM"], '2-', label="PIPERACILINA TAZOBACTAM")
plt.plot(x, datos["COLISTINA"], '*-', label="COLISTINA")
plt.plot(x, datos["LINEZOLID"], 'h-', label="LINEZOLID")
plt.plot(x, datos["POLIMIXINA B"], 'D-', label="POLIMIXINA B")
plt.xlabel('Tiempo (meses)')
plt.ylabel('Dosis')
plt.title('Tabla-1')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.plot(x, datos["k pneumonie R meropenem"], '-', label="k pneumonie R meropenem")
plt.plot(x, datos["k pneumonie R píptazo"], '--', label="k pneumonie R píptazo")
plt.plot(x, datos["p.aeruginosa R meropenem"], ':', label="p.aeruginosa R meropenem")
plt.plot(x, datos["p.aeruginosa R piptazo"], 'v-', label="p.aeruginosa R piptazo")
plt.plot(x, datos["sarrm"], 'o-', label="sarm")
plt.xlabel('Tiempo (meses)')
plt.ylabel('Resistencia')
plt.title('Tabla-2')
plt.legend()
plt.show()

# %% [markdown]
# ## Gráficas comparativas de los datos de las tablas 1, con sus respectivas respuestas de la tabla 2 (NO UCI)

# %%
plt.figure(figsize=(14,5))
plt.subplot(2, 1, 1)
plt.plot(x, datos["LINEZOLID"], 'b-', label="LINEZOLID")
plt.plot(x, 20*datos["sarrm"], "r:", label="sarm")
plt.title('RESPUESTA DE SARM A LINEZOLID y VANCOMICINA')
plt.ylabel('Dosis-respuesta')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(x, datos["VANCOMICINA"], 'b-', label="VANCOMICINA")
plt.plot(x, 20*datos["sarrm"], "r:", label="sarm")
plt.xlabel('Tiempo (meses)')
plt.ylabel('Dosis-respuesta')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.subplot(2, 1, 1)
plt.plot(x, datos["CEFTRIAXONA"], "b-", label="CEFTRIAXONA")
plt.plot(x, 3*datos["k pneumonie R meropenem"], "r--", label="k pneumonie R meropenem")
plt.plot(x, 2*datos["k pneumonie R píptazo"], "g:", label="k pneumonie R píptazo")
plt.title('RESPUESTA A CEFTRIAXONA')
plt.ylabel('Dosis-respuesta')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(x, datos["CEFTRIAXONA"], "b-", label="CEFTRIAXONA")
plt.plot(x, 2*datos["p.aeruginosa R meropenem"], "r--", label="p.aeruginosa R meropenem")
plt.plot(x, 2*datos["p.aeruginosa R piptazo"], "g:", label="p.aeruginosa R piptazo")
plt.xlabel('Tiempo (meses)')
plt.ylabel('Dosis-respuesta')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.subplot(2, 1, 1)
plt.plot(x, datos["CEFEPIMA"], "b-", label="CEFEPIMA")
plt.plot(x, 3*datos["k pneumonie R meropenem"], "r--", label="k pneumonie R meropenem")
plt.plot(x, 2*datos["k pneumonie R píptazo"], "g:", label="k pneumonie R píptazo")
plt.title('RESPUESTA A CEFEPIMA')
plt.ylabel('Dosis-respuesta')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(x, datos["CEFEPIMA"], "b-", label="CEFEPIMA")
plt.plot(x, 2*datos["p.aeruginosa R meropenem"], "r--", label="p.aeruginosa R meropenem")
plt.plot(x, 2*datos["p.aeruginosa R piptazo"], "g:", label="p.aeruginosa R piptazo")
plt.xlabel('Tiempo (meses)')
plt.ylabel('Dosis-respuesta')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.subplot(2, 1, 1)
plt.plot(x, datos["MEROPENEM"], "b-", label="MEROPENEM")
plt.plot(x, 15*datos["k pneumonie R meropenem"], "r--", label="k pneumonie R meropenem")
plt.title('RESPUESTA A MEROPENEM')
plt.ylabel('Dosis-respuesta')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(x, datos["MEROPENEM"], "b-", label="MEROPENEM")
plt.plot(x, 15*datos["p.aeruginosa R meropenem"], "r--", label="p.aeruginosa R meropenem")
plt.xlabel('Tiempo (meses)')
plt.ylabel('Dosis-respuesta')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.subplot(2, 1, 1)
plt.plot(x, datos["ERTAPENEM"], "b-", label="ERTAPENEM")
plt.plot(x, 12*datos["k pneumonie R meropenem"], "r--", label="k pneumonie R meropenem")
plt.title('RESPUESTA A ERTAPENEM')
plt.ylabel('Dosis-respuesta')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(x, datos["ERTAPENEM"], "b-", label="ERTAPENEM")
plt.plot(x, 8*datos["p.aeruginosa R meropenem"], "r--", label="p.aeruginosa R meropenem")
plt.xlabel('Tiempo (meses)')
plt.ylabel('Dosis-respuesta')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.subplot(2, 1, 1)
plt.plot(x, datos["PIPERACILINA TAZOBACTAM"], "b-", label="PIPERACILINA TAZOBACTAM")
plt.plot(x, 12*datos["k pneumonie R píptazo"], "g:", label="k pneumonie R píptazo")
plt.title('RESPUESTA A PIPERACILINA TAZOBACTAM')
plt.ylabel('Dosis-respuesta')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(x, datos["PIPERACILINA TAZOBACTAM"], "b-", label="PIPERACILINA TAZOBACTAM")

plt.plot(x, 8*datos["p.aeruginosa R piptazo"], "g:", label="p.aeruginosa R piptazo")
plt.xlabel('Tiempo (meses)')
plt.ylabel('Dosis-respuesta')
plt.legend()
plt.show()

# %% [markdown]
# ## Correlación
#
# La correlación lineal de Pearson nos da una idea de que par de variables se relacionan. Si el valor de la correlación es cercano a 1 o a -1, entonces la correlación es fuerte.

# %%
cor_1 = pd.read_excel("NOUCI_correlacion_1.xlsx", index_col=0)
cor_1 = cor_1.T

# %%
plt.figure(figsize=(6,6))
matriz = cor_1.corr()
plt.matshow(matriz, cmap="bwr", vmin=-1, vmax=1, fignum=1)
plt.xticks(range(3), cor_1.columns, rotation=90)
plt.yticks(range(3), cor_1.columns)
for i in range(len(cor_1.columns)):
    for j in range(len(cor_1.columns)):
        plt.text(i, j, round(matriz.iloc[i, j],2))
plt.colorbar()
plt.show()

# %%
cor_1.corr()
# Out:
#              VANCOMICINA  LINEZOLID     sarrm
# VANCOMICINA     1.000000   0.302094  0.052047
# LINEZOLID       0.302094   1.000000 -0.101259
# sarrm           0.052047  -0.101259  1.000000

# %%
cor_2 = pd.read_excel("NOUCI_correlacion_2.xlsx", index_col=0)
cor_2 = cor_2.T
cor_2.head()
# Out:
#             CEFTRIAXONA  CEFEPIMA  MEROPENEM  ERTAPENEM  PIPERACILINA  \
# Unnamed: 1          9.3       8.9        9.6        2.9           7.4
# Unnamed: 2          6.6       5.1        4.7        4.2           8.4
# Unnamed: 3          5.2       6.1        7.2        4.3           3.1
# Unnamed: 4          6.6       5.3        6.7        1.3           6.5
# Unnamed: 5          7.7       7.9        3.6        4.9           6.9
#
#                 kprm      kprp      parm      parp
# Unnamed: 1  0.065941  0.049456  0.016485  0.032971
# Unnamed: 2  0.028466  0.028466  0.014233  0.000000
# Unnamed: 3  0.000000  0.000000  0.000000  0.000000
# Unnamed: 4  0.000000  0.000000  0.043253  0.014418
# Unnamed: 5  0.028401  0.042602  0.028401  0.014201

# %%
plt.figure(figsize=(10,10))
matriz = cor_2.corr()
plt.matshow(matriz, cmap="bwr", vmin=-1, vmax=1, fignum=1)
plt.xticks(range(9), cor_2.columns, rotation=90)
plt.yticks(range(9), cor_2.columns)
for i in range(9):
    for j in range(9):
        plt.text(i, j, round(matriz.iloc[i, j],2))
plt.colorbar()
plt.show()

# %%
cor_2.corr()
# Out:
#               CEFTRIAXONA  CEFEPIMA  MEROPENEM  ERTAPENEM  PIPERACILINA  \
# CEFTRIAXONA      1.000000  0.673428   0.449903   0.025015      0.283256
# CEFEPIMA         0.673428  1.000000   0.486624  -0.005772      0.175525
# MEROPENEM        0.449903  0.486624   1.000000  -0.273103      0.283361
# ERTAPENEM        0.025015 -0.005772  -0.273103   1.000000     -0.346744
# PIPERACILINA     0.283256  0.175525   0.283361  -0.346744      1.000000
# kprm            -0.094895 -0.083734   0.365647  -0.387812      0.488373
# kprp            -0.190868 -0.080441   0.204729  -0.355764      0.599886
# parm            -0.219709 -0.194751   0.267137  -0.355338      0.257328
# parp            -0.105801 -0.263580   0.254729  -0.323029      0.465414
#
#                   kprm      kprp      parm      parp
# CEFTRIAXONA  -0.094895 -0.190868 -0.219709 -0.105801
# CEFEPIMA     -0.083734 -0.080441 -0.194751 -0.263580
# MEROPENEM     0.365647  0.204729  0.267137  0.254729
# ERTAPENEM    -0.387812 -0.355764 -0.355338 -0.323029
# PIPERACILINA  0.488373  0.599886  0.257328  0.465414
# kprm          1.000000  0.886273  0.604245  0.767080
# kprp          0.886273  1.000000  0.518859  0.659730
# parm          0.604245  0.518859  1.000000  0.567781
# parp          0.767080  0.659730  0.567781  1.000000
